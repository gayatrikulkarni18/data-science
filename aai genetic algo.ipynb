# %%
import random
import string

# Genetic Algorithm parameters
target_string = "HELLO"
population_size = 50  # Increased population size
mutation_rate = 0.01
generations = 200  # Increased generations for more evolution

# Fitness function: number of characters matching the target
def fitness(individual):
    return sum(1 for a, b in zip(individual, target_string) if a == b)

# Create initial population (random strings)
def create_population(size):
    return [''.join(random.choices(string.ascii_uppercase, k=len(target_string))) for _ in range(size)]

# Select parents (tournament selection)
def select_parents(population):
    tournament = random.sample(population, 5)  # Select 5 individuals instead of 3 for better diversity
    return max(tournament, key=fitness)

# Crossover (single-point crossover)
def crossover(parent1, parent2):
    crossover_point = random.randint(1, len(parent1) - 1)
    return parent1[:crossover_point] + parent2[crossover_point:]

# Mutation (random character mutation)
def mutate(individual):
    individual = list(individual)
    for i in range(len(individual)):
        if random.random() < mutation_rate:
            individual[i] = random.choice(string.ascii_uppercase)
    return ''.join(individual)

# Main genetic algorithm loop
population = create_population(population_size)
for generation in range(generations):
    best_individual = max(population, key=fitness)
    print(f"Generation {generation}: Best individual: {best_individual}, Fitness: {fitness(best_individual)}")
    
    if fitness(best_individual) == len(target_string):  # Stop early if the optimal solution is found
        break
    
    # Create new generation
    new_population = []
    for _ in range(population_size):
        parent1 = select_parents(population)
        parent2 = select_parents(population)
        child = crossover(parent1, parent2)
        child = mutate(child)
        new_population.append(child)
    
    population = new_population

# Best individual in the final population
best_individual = max(population, key=fitness)
print(f"Best individual: {best_individual}, Fitness: {fitness(best_individual)}")
print('Gayatri Kulkarni-53004230002')
# Out:
# Generation 0: Best individual: PEYVO, Fitness: 2
# Generation 1: Best individual: OEVVO, Fitness: 2
# Generation 2: Best individual: PEOLO, Fitness: 3
# Generation 3: Best individual: HEYSO, Fitness: 3
# Generation 4: Best individual: HEOLO, Fitness: 4
# Generation 5: Best individual: HEOLO, Fitness: 4
# Generation 6: Best individual: HEOLO, Fitness: 4
# Generation 7: Best individual: HEOLO, Fitness: 4
# Generation 8: Best individual: HEYLO, Fitness: 4
# Generation 9: Best individual: HEYLO, Fitness: 4
# Generation 10: Best individual: HEOLO, Fitness: 4
# Generation 11: Best individual: HEOLO, Fitness: 4
# Generation 12: Best individual: HEOLO, Fitness: 4
# Generation 13: Best individual: HEOLO, Fitness: 4
# Generation 14: Best individual: HEYLO, Fitness: 4
# Generation 15: Best individual: HEOLO, Fitness: 4
# Generation 16: Best individual: HEOLO, Fitness: 4
# Generation 17: Best individual: HEOLO, Fitness: 4
# Generation 18: Best individual: HEYLO, Fitness: 4
# Generation 19: Best individual: HEYLO, Fitness: 4
# Generation 20: Best individual: HESLO, Fitness: 4
# Generation 21: Best individual: HEDLO, Fitness: 4
# Generation 22: Best individual: HEOLO, Fitness: 4
# Generation 23: Best individual: HEYLO, Fitness: 4
# Generation 24: Best individual: HEYLO, Fitness: 4
# Generation 25: Best individual: HEOLO, Fitness: 4
# Generation 26: Best individual: HEALO, Fitness: 4
# Generation 27: Best individual: HEXLO, Fitness: 4
# Generation 28: Best individual: HEOLO, Fitness: 4
# Generation 29: Best individual: HEYLO, Fitness: 4
# Generation 30: Best individual: HEXLO, Fitness: 4
# Generation 31: Best individual: HEOLO, Fitness: 4
# Generation 32: Best individual: HEALO, Fitness: 4
# Generation 33: Best individual: HEOLO, Fitness: 4
# Generation 34: Best individual: HEDLO, Fitness: 4
# Generation 35: Best individual: HEDLO, Fitness: 4
# Generation 36: Best individual: HEALO, Fitness: 4
# Generation 37: Best individual: HEXLO, Fitness: 4
# Generation 38: Best individual: HEDLO, Fitness: 4
# Generation 39: Best individual: HEXLO, Fitness: 4
# Generation 40: Best individual: HEXLO, Fitness: 4
# Generation 41: Best individual: HEOLO, Fitness: 4
# Generation 42: Best individual: HEYLO, Fitness: 4
# Generation 43: Best individual: HEOLO, Fitness: 4
# Generation 44: Best individual: HEDLO, Fitness: 4
# Generation 45: Best individual: HEYLO, Fitness: 4
# Generation 46: Best individual: HEYLO, Fitness: 4
# Generation 47: Best individual: HEOLO, Fitness: 4
# Generation 48: Best individual: HEOLO, Fitness: 4
# Generation 49: Best individual: HEMLO, Fitness: 4
# Generation 50: Best individual: HEOLO, Fitness: 4
# Generation 51: Best individual: HEYLO, Fitness: 4
# Generation 52: Best individual: HEMLO, Fitness: 4
# Generation 53: Best individual: HEOLO, Fitness: 4
# Generation 54: Best individual: HEYLO, Fitness: 4
# Generation 55: Best individual: HEYLO, Fitness: 4
# Generation 56: Best individual: HEYLO, Fitness: 4
# Generation 57: Best individual: HEMLO, Fitness: 4
# Generation 58: Best individual: HEYLO, Fitness: 4
# Generation 59: Best individual: HEYLO, Fitness: 4
# Generation 60: Best individual: HEYLO, Fitness: 4
# Generation 61: Best individual: HEYLO, Fitness: 4
# Generation 62: Best individual: HEYLO, Fitness: 4
# Generation 63: Best individual: HEYLO, Fitness: 4
# Generation 64: Best individual: HEPLO, Fitness: 4
# Generation 65: Best individual: HEOLO, Fitness: 4
# Generation 66: Best individual: HEMLO, Fitness: 4
# Generation 67: Best individual: HEYLO, Fitness: 4
# Generation 68: Best individual: HEMLO, Fitness: 4
# Generation 69: Best individual: HEYLO, Fitness: 4
# Generation 70: Best individual: HEOLO, Fitness: 4
# Generation 71: Best individual: HEMLO, Fitness: 4
# Generation 72: Best individual: HEVLO, Fitness: 4
# Generation 73: Best individual: HEYLO, Fitness: 4
# Generation 74: Best individual: HEVLO, Fitness: 4
# Generation 75: Best individual: HEYLO, Fitness: 4
# Generation 76: Best individual: HEYLO, Fitness: 4
# Generation 77: Best individual: HEVLO, Fitness: 4
# Generation 78: Best individual: HEMLO, Fitness: 4
# Generation 79: Best individual: HEYLO, Fitness: 4
# Generation 80: Best individual: HEMLO, Fitness: 4
# Generation 81: Best individual: HEULO, Fitness: 4
# Generation 82: Best individual: HEMLO, Fitness: 4
# Generation 83: Best individual: HEMLO, Fitness: 4
# Generation 84: Best individual: HEMLO, Fitness: 4
# Generation 85: Best individual: HEMLO, Fitness: 4
# Generation 86: Best individual: HEMLO, Fitness: 4
# Generation 87: Best individual: HEYLO, Fitness: 4
# Generation 88: Best individual: HEYLO, Fitness: 4
# Generation 89: Best individual: HEYLO, Fitness: 4
# Generation 90: Best individual: HEYLO, Fitness: 4
# Generation 91: Best individual: HEMLO, Fitness: 4
# Generation 92: Best individual: HEMLO, Fitness: 4
# Generation 93: Best individual: HEMLO, Fitness: 4
# Generation 94: Best individual: HEYLO, Fitness: 4
# Generation 95: Best individual: HEMLO, Fitness: 4
# Generation 96: Best individual: HEMLO, Fitness: 4
# Generation 97: Best individual: HEMLO, Fitness: 4
# Generation 98: Best individual: HEYLO, Fitness: 4
# Generation 99: Best individual: HEULO, Fitness: 4
# Generation 100: Best individual: HETLO, Fitness: 4
# Generation 101: Best individual: HETLO, Fitness: 4
# Generation 102: Best individual: HEULO, Fitness: 4
# Generation 103: Best individual: HEMLO, Fitness: 4
# Generation 104: Best individual: HEYLO, Fitness: 4
# Generation 105: Best individual: HEULO, Fitness: 4
# Generation 106: Best individual: HEMLO, Fitness: 4
# Generation 107: Best individual: HEYLO, Fitness: 4
# Generation 108: Best individual: HEULO, Fitness: 4
# Generation 109: Best individual: HEMLO, Fitness: 4
# Generation 110: Best individual: HEWLO, Fitness: 4
# Generation 111: Best individual: HEWLO, Fitness: 4
# Generation 112: Best individual: HEWLO, Fitness: 4
# Generation 113: Best individual: HEWLO, Fitness: 4
# Generation 114: Best individual: HEWLO, Fitness: 4
# Generation 115: Best individual: HEMLO, Fitness: 4
# Generation 116: Best individual: HEYLO, Fitness: 4
# Generation 117: Best individual: HEMLO, Fitness: 4
# Generation 118: Best individual: HEWLO, Fitness: 4
# Generation 119: Best individual: HEMLO, Fitness: 4
# Generation 120: Best individual: HEMLO, Fitness: 4
# Generation 121: Best individual: HEWLO, Fitness: 4
# Generation 122: Best individual: HEMLO, Fitness: 4
# Generation 123: Best individual: HEMLO, Fitness: 4
# Generation 124: Best individual: HEBLO, Fitness: 4
# Generation 125: Best individual: HEYLO, Fitness: 4
# Generation 126: Best individual: HEJLO, Fitness: 4
# Generation 127: Best individual: HEWLO, Fitness: 4
# Generation 128: Best individual: HEMLO, Fitness: 4
# Generation 129: Best individual: HEMLO, Fitness: 4
# Generation 130: Best individual: HEJLO, Fitness: 4
# Generation 131: Best individual: HEMLO, Fitness: 4
# Generation 132: Best individual: HEBLO, Fitness: 4
# Generation 133: Best individual: HEBLO, Fitness: 4
# Generation 134: Best individual: HELLO, Fitness: 5
# Best individual: HELLO, Fitness: 5
# Gayatri Kulkarni-53004230002
